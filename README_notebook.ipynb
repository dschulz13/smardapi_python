# %% [markdown]
# # smardapi
#
# This is a Python package for specifying, downloading, plotting and saving time series data from the [SMARD API](https://smard.api.bund.dev/) of the German Federal Network Agency.
#
# ## Installation
#
# Install the latest package version from GitHub via entering the following in the terminal:

# %% [markdown]
# ```pip install git+https://github.com/dschulz13/smardapi_python.git```

# %% [markdown]
# ## Example
#
# Firstly, import the module under a self-selected name. This is already a working instance of the class "SmardApi".

# %%
import smardapi as smard

# %% [markdown]
# Then specify the series and region via `smard.specify()`. For available options, call `smard.allowed_filter_no()` and `smard.allowed_region()`.

# %%
smard.specify(filter_no = 410, region = "DE")

# %% [markdown]
# The previos code specifies the region as Germany (`region = "DE"`) and the series to be the total electricity consumption (`filter_no = 410`).
#
# Afterwards, we are ready to download the data via `smard.download()`.

# %%
smard.download(resolution = "day", start = "2016-03-15", stop = "2023-05-11")
# Out:
# Downloading data...
# Download successful!
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 smard.download(resolution = "day", start = "2016-03-15", stop = "2023-05-11")
#
# File C:\Anaconda\Lib\site-packages\smardapi\SmardApi_Class.py:263, in SmardApi.download(self, resolution, start, stop, silent)
#     260 if stop is not None and not is_iso8601(start):
#     261     raise ValueError('stop must be either None or a string of the ISO8601 format.')
# --> 263 self.data = get_ts_data(
#     264     filter_no = self.specification['filter_no'],
#     265     region = self.specification['region'],
#     266     resolution = resolution,
#     267     start = start,
#     268     stop = stop,
#     269     silent = silent)
#
# File C:\Anaconda\Lib\site-packages\smardapi\SmardApi_Class.py:124, in get_ts_data(filter_no, region, resolution, start, stop, silent)
#     118 df = pd.DataFrame({
#     119     'Timestamp': [datetime.fromtimestamp(int(subsublist[0] / 1000), tz = ZoneInfo("Europe/Berlin")) \
#     120         for sublist in data_collection for subsublist in sublist],
#     121     'Value': [subsublist[1] for sublist in data_collection for subsublist in sublist]
#     122     })
#     123 df.drop_duplicates(subset = ['Timestamp'], ignore_index = True, inplace = True)
# --> 124 df = df.iloc[lambda x: (x['Timestamp'] >= datetime.fromisoformat(start).replace(tzinfo = ZoneInfo("Europe/Berlin"))) & (x['Timestamp'] <= datetime.fromisoformat(stop).replace(tzinfo = ZoneInfo("Europe/Berlin"))), :]
#     125 df = df.loc[df['Value'].first_valid_index():df['Value'].last_valid_index()].reset_index(drop = True)
#     126 #df.set_index('Timestamp', inplace = True)
#
# File C:\Anaconda\Lib\site-packages\pandas\core\indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File C:\Anaconda\Lib\site-packages\pandas\core\indexing.py:1691, in _iLocIndexer._getitem_tuple(self, tup)
#    1690 def _getitem_tuple(self, tup: tuple):
# -> 1691     tup = self._validate_tuple_indexer(tup)
#    1692     with suppress(IndexingError):
#    1693         return self._getitem_lowerdim(tup)
#
# File C:\Anaconda\Lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer._validate_tuple_indexer(self, key)
#     965 for i, k in enumerate(key):
#     966     try:
# --> 967         self._validate_key(k, i)
#     968     except ValueError as err:
#     969         raise ValueError(
#     970             "Location based indexing can only have "
#     971             f"[{self._valid_types}] types"
#     972         ) from err
#
# File C:\Anaconda\Lib\site-packages\pandas\core\indexing.py:1579, in _iLocIndexer._validate_key(self, key, axis)
#    1577 if hasattr(key, "index") and isinstance(key.index, Index):
#    1578     if key.index.inferred_type == "integer":
# -> 1579         raise NotImplementedError(
#    1580             "iLocation based boolean "
#    1581             "indexing on an integer type "
#    1582             "is not available"
#    1583         )
#    1584     raise ValueError(
#    1585         "iLocation based boolean indexing cannot use "
#    1586         "an indexable as a mask"
#    1587     )
#    1588 return
#
# NotImplementedError: iLocation based boolean indexing on an integer type is not available

# %% [markdown]
# `resolution` defines the observation frequency. Here, we pick daily. For an overview of the options, see `smard.allowed_resolution()`. Furthermore, `start` and `stop` are timestamps that align with the ISO8601 standard and they define the time window for which to download the data. For more granular data, like hourly data via `resolution = "hour"`, `start` and `stop` may also include times.
#
# `smard.data` now contains a `pandas` data frame with the downloaded data.

# %%
smard.data.head()

# %% [markdown]
# Now, we may wish to create a plot of the downloaded series.

# %%
smard.plot()

# %% [markdown]
# The `.plot()` method may contain any further positional or keyword arguments from `pandas.DataFrame.plot()`.
#
# The data frame in `smard.data` may also be saved locally to your device using `smard.save_csv()`.

# %% [markdown]
# ```smard.save_csv(file = "NewData.csv")```

# %% [markdown]
# ## Contact
#
# Issues can be stated at https://github.com/dschulz13/smardapi_python/issues. Otherwise, please feel free to reach out via dominik.schulz.r@gmail.com.
